# %% [markdown]
# # VGG16 Review

# %%
from keras.applications.vgg16 import VGG16

# %%
vgg16 = VGG16()

# %%
vgg16.summary()

# %%
vgg16_weights = vgg16.get_weights()
print(type(vgg16_weights), len(vgg16_weights))

# %%
print(len(vgg16.layers))
for layer in vgg16_weights:
    print(len(layer))

# %% [markdown]
# # FCN32 Review

# %%
from models.fcn32 import FCN32
# Out:
# Using TensorFlow backend.

# %%
fcn32 = FCN32()

# %%
fcn32.summary()

# %%
fcn32_weights = fcn32.get_weights()
print(type(fcn32_weights), len(fcn32_weights))

# %%
print(len(fcn32.layers))
for layer in fcn32_weights:
    print(len(layer))

# %% [markdown]
# # FCN32 Training

# %%
from keras import optimizers
from utils.loss_and_metric import dice_coef, dice_coef_loss

# %%
adam = optimizers.Adam(lr=1e-6, beta_1=0.9, beta_2=0.999, epsilon=1e-08, decay=0.0)
fcn32.compile(loss=dice_coef_loss,
              optimizer=adam,
              metrics=[dice_coef])

# %%
for i in range(18):
    fcn32.layers[i].set_weights(vgg16.layers[i+1].get_weights())

# %%
from data import load_data

imgs, masks = load_data()

# %%
print(type(imgs), imgs.shape)
print(type(masks), masks.shape)

# %%
# run on gpu0
import os
os.environ['CUDA_VISIBLE_DEVICES'] = '0'

# %%
fcn32_history = fcn32.fit(imgs, masks, 
          batch_size=16, 
          epochs=2,
          verbose=1,
          validation_split=0.2)

# %%
# Save model and weights

save_dir = os.path.join(os.getcwd(), 'saved_models')
model_name = 'fcn32.h5'

if not os.path.isdir(save_dir):
    os.makedirs(save_dir)
model_path = os.path.join(save_dir, model_name)
fcn32.save(model_path)
print('Saved trained model at %s ' % model_path)

# %% [markdown]
# # FCN32 Prediction

# %%
fcn32.load_weights("saved_models/fcn32_7761.h5")

# %%
from utils.prediction import predict
mask = predict(fcn32, "VOCdevkit/VOC2012/JPEGImages/2007_000033.jpg")

# %% [markdown]
# # FCN16 Review

# %%
from models.fcn16 import FCN16

# %%
fcn16 = FCN16()

# %%
fcn16.summary()

# %%
fcn16_weights = fcn16.get_weights()
print(type(fcn16_weights), len(fcn16_weights))

# %%
print(len(fcn16.layers))
for layer in fcn16_weights:
    print(len(layer))

# %% [markdown]
# # FCN16 Training

# %%
from keras import optimizers
from utils.loss_and_metric import dice_coef, dice_coef_loss

# %%
adam = optimizers.Adam(lr=1e-5, beta_1=0.9, beta_2=0.999, epsilon=1e-08, decay=0.0)
fcn16.compile(loss=dice_coef_loss,
              optimizer=adam,
              metrics=[dice_coef])

# %%
for i in range(23):
    fcn16.layers[i+1].set_weights(fcn32.layers[i].get_weights())

# %%
from data import load_data

imgs, masks = load_data()

# %%
# run on gpu0
import os
os.environ['CUDA_VISIBLE_DEVICES'] = '0'

# %%
fcn16_history = fcn16.fit(imgs, masks, 
          batch_size=16, 
          epochs=5,
          verbose=1,
          validation_split=0.2)
# Out:
# Train on 2330 samples, validate on 583 samples
# Epoch 1/5
# 2330/2330 [==============================] - 244s - loss: -0.7892 - dice_coef: 0.7892 - val_loss: -0.7778 - val_dice_coef: 0.7778
# Epoch 2/5
# 2330/2330 [==============================] - 232s - loss: -0.8545 - dice_coef: 0.8545 - val_loss: -0.7801 - val_dice_coef: 0.7801
# Epoch 3/5
# 2330/2330 [==============================] - 232s - loss: -0.8631 - dice_coef: 0.8631 - val_loss: -0.7796 - val_dice_coef: 0.7796
# Epoch 4/5
# 2330/2330 [==============================] - 232s - loss: -0.8702 - dice_coef: 0.8702 - val_loss: -0.7823 - val_dice_coef: 0.7823
# Epoch 5/5
# 2330/2330 [==============================] - 232s - loss: -0.8744 - dice_coef: 0.8744 - val_loss: -0.7835 - val_dice_coef: 0.7835

# %%
# Save model and weights

save_dir = os.path.join(os.getcwd(), 'saved_models')
model_name = 'fcn16.h5'

if not os.path.isdir(save_dir):
    os.makedirs(save_dir)
model_path = os.path.join(save_dir, model_name)
fcn16.save(model_path)
print('Saved trained model at %s ' % model_path)
# Out:
# Saved trained model at /home/charlioxumykj/Documents/image-classification-segmentation/saved_models/fcn16.h5

# %% [markdown]
# # FCN16 Prediction

# %%
fcn16.load_weights("saved_models/fcn16_7835.h5")

# %%
from utils.prediction import predict
mask = predict(fcn16, "VOCdevkit/VOC2012/JPEGImages/2007_000033.jpg")
# Out:
# /home/charlioxumykj/miniconda3/envs/dlnd/lib/python3.6/site-packages/skimage/transform/_warps.py:84: UserWarning: The default mode, 'constant', will be changed to 'reflect' in skimage 0.15.
#   warn("The default mode, 'constant', will be changed to 'reflect' in "
